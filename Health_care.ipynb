# %%
##  https://www.kaggle.com/datasets/prasad22/healthcare-dataset

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\Downloads\Project\healthcare_dataset.csv")
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df.count()
# Out:
# Name                  10000
# Age                   10000
# Gender                10000
# Blood Type            10000
# Medical Condition     10000
# Date of Admission     10000
# Doctor                10000
# Hospital              10000
# Insurance Provider    10000
# Billing Amount        10000
# Room Number           10000
# Admission Type        10000
# Discharge Date        10000
# Medication            10000
# Test Results          10000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
## Creating a copy

# %%
df1 = df.copy()

# %%
## Using df1

# %%
df1.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df1.count()
# Out:
# Name                  10000
# Age                   10000
# Gender                10000
# Blood Type            10000
# Medical Condition     10000
# Date of Admission     10000
# Doctor                10000
# Hospital              10000
# Insurance Provider    10000
# Billing Amount        10000
# Room Number           10000
# Admission Type        10000
# Discharge Date        10000
# Medication            10000
# Test Results          10000
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df1.drop(['Name', 'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
       'Billing Amount', 'Room Number','Discharge Date'], axis=1, inplace=True)

# %%
df1.head()
# Out:
#    Age  Gender Blood Type Medical Condition Admission Type   Medication  \
# 0   81  Female         O-          Diabetes       Elective      Aspirin
# 1   35    Male         O+            Asthma      Emergency      Lipitor
# 2   61    Male         B-           Obesity      Emergency      Lipitor
# 3   49    Male         B-            Asthma         Urgent   Penicillin
# 4   51    Male         O-         Arthritis         Urgent  Paracetamol
#
#    Test Results
# 0  Inconclusive
# 1        Normal
# 2        Normal
# 3      Abnormal
# 4        Normal

# %%
df1['Blood Type'].value_counts()
# Out:
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: Blood Type, dtype: int64

# %%
df1['Medical Condition'].value_counts()
# Out:
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: Medical Condition, dtype: int64

# %%
df1['Admission Type'].value_counts()
# Out:
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: Admission Type, dtype: int64

# %%
df1['Medication'].value_counts()
# Out:
# Penicillin     2079
# Lipitor        2015
# Ibuprofen      1976
# Aspirin        1968
# Paracetamol    1962
# Name: Medication, dtype: int64

# %%
df1['Test Results'].value_counts()
# Out:
# Abnormal        3456
# Inconclusive    3277
# Normal          3267
# Name: Test Results, dtype: int64

# %%
# df1.head()

# %%
df1['Gender'] = np.where(df['Gender'] == "Male" , 1,0)
le = LabelEncoder()
df1['Blood Type'] = le.fit_transform(df1['Blood Type'])
df1['Medical Condition'] = le.fit_transform(df1['Medical Condition'])
df1['Admission Type'] = le.fit_transform(df1['Admission Type'])
df1['Medication'] = le.fit_transform(df1['Medication'])
df1['Test Results'] = le.fit_transform(df1['Test Results'])

# %%
df1.head()
# Out:
#    Age  Gender  Blood Type  Medical Condition  Admission Type  Medication  \
# 0   81       0           7                  3               0           0
# 1   35       1           6                  1               1           2
# 2   61       1           5                  5               1           2
# 3   49       1           5                  1               2           4
# 4   51       1           7                  0               2           3
#
#    Test Results
# 0             1
# 1             2
# 2             2
# 3             0
# 4             2

# %%
df1.describe()
# Out:
#                 Age        Gender    Blood Type  Medical Condition  \
# count  10000.000000  10000.000000  10000.000000       10000.000000
# mean      51.452200      0.492500      3.501100           2.487500
# std       19.588974      0.499969      2.286071           1.701803
# min       18.000000      0.000000      0.000000           0.000000
# 25%       35.000000      0.000000      2.000000           1.000000
# 50%       52.000000      0.000000      3.000000           2.000000
# 75%       68.000000      1.000000      5.000000           4.000000
# max       85.000000      1.000000      7.000000           5.000000
#
#        Admission Type   Medication  Test Results
# count    10000.000000  10000.00000  10000.000000
# mean         1.014900      2.02080      0.981100
# std          0.814337      1.41858      0.819762
# min          0.000000      0.00000      0.000000
# 25%          0.000000      1.00000      0.000000
# 50%          1.000000      2.00000      1.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
count, bin_edges = np.histogram(df1['Age'])
df['Age'].plot(kind='hist', xticks=bin_edges)
plt.figure(figsize=(5,5))
plt.show()

# %%
plt.hist(df['Blood Type'], bins=10)
plt.show()

# %%
df['Age'].plot(kind='box')
plt.show()

# %%
df1.plot(kind='scatter', x='Blood Type', y='Age')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

noise = df1['Age']
density = stats.gaussian_kde(noise)
n, x, _ = plt.hist(noise, bins=np.linspace(0, 100, 150), 
                   histtype=u'step', density=True)  
plt.plot(x, density(x))
plt.show()

# %%
import seaborn as sns
sns.pairplot(df1, hue="Test Results")

# %%
sns.heatmap(df1.corr(), annot=True)
plt.figure(figsize=(10,8))

# %%
X = df1.drop(['Test Results'], axis=1)
Y = df1['Test Results']

# %%
X[:5]
# Out:
#    Age  Gender  Blood Type  Medical Condition  Admission Type  Medication
# 0   81       0           7                  3               0           0
# 1   35       1           6                  1               1           2
# 2   61       1           5                  5               1           2
# 3   49       1           5                  1               2           4
# 4   51       1           7                  0               2           3

# %%
Y[:5]
# Out:
# 0    1
# 1    2
# 2    2
# 3    0
# 4    2
# Name: Test Results, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train,Y_test = train_test_split(X,Y, test_size=0.25, random_state= 40)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (7500, 6)
# (2500, 6)
# (7500,)
# (2500,)

# %%
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()

# %%
X_train = scaling.fit_transform(X_train)

# %%
X_test = scaling.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.58512313, -0.99044564, -1.1003293 , -0.86735243, -1.24824856,
#         -0.01136148],
#        [-0.69570468, -0.99044564, -0.66292697,  0.89222107, -1.24824856,
#         -0.01136148],
#        [-1.25926891, -0.99044564, -0.22552464, -0.86735243, -1.24824856,
#          0.69286275],
#        ...,
#        [ 1.14868736, -0.99044564,  1.08668234,  0.30569657, -1.24824856,
#         -0.01136148],
#        [ 0.43142379,  1.00964653,  1.52408467,  1.47874557,  1.21345647,
#          0.69286275],
#        [ 0.32895757, -0.99044564, -1.53773163, -1.45387693, -0.01739605,
#         -0.71558572]])

# %%
a = pd.DataFrame(a, columns= ['Age','Gender','Blood Type','Medical Condition','Admission Type','Medication','Test Results'])
sns.heatmap(a.corr(), annot=True)
plt.figure(figsize=(10,8))

# %%
a
# Out:
#            Age    Gender  Blood Type  Medical Condition  Admission Type  \
# 0     1.508465 -0.985111    1.530606           0.301166       -1.246353
# 1    -0.839912  1.015114    1.093153          -0.874117       -0.018298
# 2     0.487431  1.015114    0.655699           1.476449       -0.018298
# 3    -0.125189  1.015114    0.655699          -0.874117        1.209757
# 4    -0.023086  1.015114    1.530606          -1.461758        1.209757
# ...        ...       ...         ...                ...             ...
# 9995  1.610568  1.015114   -1.531569           1.476449       -1.246353
# 9996 -0.227292 -0.985111   -0.656662          -1.461758       -0.018298
# 9997  0.130069  1.015114    0.655699          -1.461758       -1.246353
# 9998  1.661620  1.015114   -1.531569          -1.461758        1.209757
# 9999 -1.605688  1.015114    0.655699          -1.461758       -0.018298
#
#       Medication  Test Results
# 0      -1.424595      0.023057
# 1      -0.014663      1.242984
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

noise = a['Age']
density = stats.gaussian_kde(noise)
n, x, _ = plt.hist(noise, bins=np.linspace(-2, 2, 150), 
                   histtype=u'step', density=True)  
plt.plot(x, density(x))
plt.show()

# %%
## Importing model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# %%
## Finding the best parameters for RandomForestClassifier.

# %%
parameters = {'max_depth' :[3,5,6,7,10],
              'max_features': ["sqrt", "log2", None],
              'n_estimators': [50,100,200,300,400,500],
              'criterion' : ['gini', 'log_loss', 'entropy'],
              'bootstrap':[True, False],
             'min_samples_leaf': randint(1, 7)}

# %%
rf_clf = RandomForestClassifier()

# %%
rfc = RandomizedSearchCV(estimator = rf_clf, param_distributions = parameters, n_iter = 10, cv = 2, verbose = 10, random_state= 42, n_jobs=-1)

# %%
fm = rfc.fit(X_train, Y_train)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits

# %%
fm.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'log_loss',
#  'max_depth': 3,
#  'max_features': 'log2',
#  'min_samples_leaf': 5,
#  'n_estimators': 100}

# %%
fm.best_score_
# Out:
# 0.34306666666666663

# %%
rf_clf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred = rf_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score = accuracy_score(Y_test, Y_pred)
acc_score
# Out:
# 0.3504

# %%
# from sklearn.model_selection import GridSearchCV

# %%
from sklearn.metrics import confusion_matrix

# %%
confu = confusion_matrix(Y_test , Y_pred)
sns.heatmap(confu, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test ,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.34      0.36      0.35       840
#            1       0.37      0.35      0.36       851
#            2       0.34      0.34      0.34       809
#
#     accuracy                           0.35      2500
#    macro avg       0.35      0.35      0.35      2500
# weighted avg       0.35      0.35      0.35      2500
